# %% [markdown]
# #BostonHousing_dataset_project
# Downloaded BostonHousing dataset and already loaded it..
#
# Import necessary libraries.!
#
#
# pandas as pd,
#
#
# numpy as np,
#
#
# matplotlib as plt

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loaded dataset

# %%
housing_dataset = pd.read_csv('/content/BostonHousing.csv')

# %% [markdown]
# Display the first five rows

# %%
housing_dataset.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# Show data types of the dataset

# %%
housing_dataset.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# b          float64
# lstat      float64
# medv       float64
# dtype: object

# %% [markdown]
# Show missing values

# %%
housing_dataset.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         5
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %% [markdown]
# Show outlier in dataset using sns

# %%
plt.figure(figsize = (12, 16))
sns.boxplot(data=housing_dataset)
plt.xticks(rotation=90)
plt.show()

# %%
housing_dataset['rm'].fillna(housing_dataset['rm'].median(),
inplace=True)

# %%
housing_dataset['rm'].isnull().sum()
# Out:
# 0

# %%
sns.set(rc={"figure.figsize":(20 , 8)})
sns.histplot(housing_dataset['b'],bins=20);
