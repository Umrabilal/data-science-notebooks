# %% [markdown]
# # YouTube video downloader

# %%
pip install yt-dlp
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.1/170.1 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 13.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.3/157.3 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 24.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 30.8 MB/s eta 0:00:00
# ...

# %%
# !pip install yt-dlp

# %%
import yt_dlp

# Prompting for URL
url = input("https://youtube.com/shorts/rW6dtW-I8Es?si=Vk1LhgpoTfkmIdne: ")

# Options for downloading
ydl_opts = {'no-check-certificate': True}

# Downloading the video
with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.download([url])

print("Video downloaded successfully!")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-bbec5cd23c84> in <cell line: 4>()
#       2
#       3 # Prompting for URL
# ----> 4 url = input("https://youtube.com/shorts/rW6dtW-I8Es?si=Vk1LhgpoTfkmIdne: ")
#       5
#       6 # Options for downloading
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
import yt_dlp

# Set the YouTube video URL manually
url = "https://youtu.be/eJbMBCBqs5A?si=u2sXSeALdn0viSPH"

# Options for downloading
ydl_opts = {}

# Downloading the video
with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.download([url])

print("Video downloaded successfully!")
# Out:
# [youtube] Extracting URL: https://youtube.com/shorts/Yov6t2DNYDQ?si=Fojbfggm03kCFdPL
# [youtube] Yov6t2DNYDQ: Downloading webpage
# [youtube] Yov6t2DNYDQ: Downloading ios player API JSON
# [youtube] Yov6t2DNYDQ: Downloading android player API JSON
# [youtube] Yov6t2DNYDQ: Downloading m3u8 information
# [info] Yov6t2DNYDQ: Downloading 1 format(s): 616+251
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 1
# [download] Destination: daddy and baby 😘😘 [Yov6t2DNYDQ].f616.mp4
# [download] 100% of    4.07MiB in 00:00:00 at 19.69MiB/s
# [download] Destination: daddy and baby 😘😘 [Yov6t2DNYDQ].f251.webm
# [download] 100% of  116.72KiB in 00:00:00 at 4.34MiB/s
# [Merger] Merging formats into "daddy and baby 😘😘 [Yov6t2DNYDQ].webm"
# Deleting original file daddy and baby 😘😘 [Yov6t2DNYDQ].f251.webm (pass -k to keep)
# Deleting original file daddy and baby 😘😘 [Yov6t2DNYDQ].f616.mp4 (pass -k to keep)
# Video downloaded successfully!

# %%
import yt_dlp

# Set the YouTube video URL manually
url = "https://youtu.be/eJbMBCBqs5A?si=u2sXSeALdn0viSPH"

# Options for downloading
ydl_opts = {}

# Downloading the video
with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.download([url])

print("Video downloaded successfully!")
# Out:
# [youtube] Extracting URL: https://youtu.be/eJbMBCBqs5A?si=u2sXSeALdn0viSPH
# [youtube] eJbMBCBqs5A: Downloading webpage
# [youtube] eJbMBCBqs5A: Downloading ios player API JSON
# [youtube] eJbMBCBqs5A: Downloading android player API JSON
# [youtube] eJbMBCBqs5A: Downloading m3u8 information
# [info] eJbMBCBqs5A: Downloading 1 format(s): 248+251
# [download] Ulama kay Khilaf Ulama ko kese Estemal kia gaya ｜ Youth counselling series ｜ Epiosde 2 [eJbMBCBqs5A].webm has already been downloaded
# Video downloaded successfully!

# %%
import yt_dlp

# Set the YouTube video URL manually
url = "https://youtu.be/KOPvzZ41HRU"

# Options for downloading
ydl_opts = {}

# Downloading the video
with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.download([url])

print("Video downloaded successfully!")
# Out:
# [youtube] Extracting URL: https://youtu.be/KOPvzZ41HRU
# [youtube] KOPvzZ41HRU: Downloading webpage
# [youtube] KOPvzZ41HRU: Downloading ios player API JSON
# [youtube] KOPvzZ41HRU: Downloading web creator player API JSON
# [youtube] KOPvzZ41HRU: Downloading m3u8 information
# [info] KOPvzZ41HRU: Downloading 1 format(s): 616+251
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 36
# [download] Destination: Main Khuda Ko Bataunga - Lyrical ｜ Amjad Baltistani ｜ Ek Phool Tha Mai Jo Khil Na Saka ｜ TNA RECORDS [KOPvzZ41HRU].f616.mp4
# [download] 100% of   16.84MiB in 00:00:05 at 3.20MiB/s
# [download] Destination: Main Khuda Ko Bataunga - Lyrical ｜ Amjad Baltistani ｜ Ek Phool Tha Mai Jo Khil Na Saka ｜ TNA RECORDS [KOPvzZ41HRU].f251.webm
# [download] 100% of    3.20MiB in 00:00:00 at 13.50MiB/s
# [Merger] Merging formats into "Main Khuda Ko Bataunga - Lyrical ｜ Amjad Baltistani ｜ Ek Phool Tha Mai Jo Khil Na Saka ｜ TNA RECORDS [KOPvzZ41HRU].webm"
# ...

# %% [markdown]
# # New Section
